# %% [markdown]
# <h1>Cyclistic Bike-Share Analysis</h1>

# %% [markdown]
# <B>Author:</B> Dror Givon</br>
# <B>Date:</B> February 5, 2022

# %% [markdown]
# <h3>Introduction</h3>

# %% [markdown]
# This notebook contains the first case study of Google's Data Analytics Professional Certificate. The case study requires the analyst to follow to the steps of the data analysis process (ask, prepare, process, analyze, share,and act) for a dataset that represents a fictional company (Cyclistic Bike-Share).

# %% [markdown]
# <h3>Data Analysis method:</h3>
# <h5>Ask -> Prepare -> Process -> Analyze -> Share -> Act</h5>

# %% [markdown]
# <h1>1. Ask</h1>

# %% [markdown]
# <h3>Background</h3>

# %% [markdown]
# * Company: Cyclistic, a fictional bike-share company based in Chicago launched a successful bike-share offering. Since then, the program has grown to a fleet of 5,824 bicycles that are geo-tracked and locked into a network of 692 stations across Chicago. The bikes can be unlocked from one station and returned to any other station in the system anytime. Until now, Cyclistic’s marketing strategy relied on building general awareness and appealing to broad consumer segments. One approach that helped make these things possible was the flexibility of its pricing plans: single-ride passes, full-day passes, and annual memberships. Customers who purchase single-ride or full-day passes are referred to as casual riders. Customers who purchase annual memberships are Cyclistic members.
# </br></br>
# *  My role: Junior data analyst working in the marketing analytics team.
# </br></br>
# *  Premise: Cyclistic’s finance analysts have concluded that annual members are much more profitable than casual riders. The director of marketing (who is also my manager) believes there is a very good chance to convert casual riders into members. She notes that casual riders are already aware of the Cyclistic program and have chosen Cyclistic for their mobility needs. The director of marketing wants to Design marketing strategies aimed at converting casual riders into annual members but to do this, the marketing analyst team needs to better understand how annual members and casual riders differ, why casual riders would buy a membership, and how digital media could affect their marketing tactics. So there’s need to analyze the Cyclistic historical bike trip data to identify trends.

# %% [markdown]
# <h3>The Business Task:</h3>

# %% [markdown]
# My task is to analyze the Cyclistic historical bike trip data to identify trends that will help the marketing team to convert casual riders into members.

# %% [markdown]
# <h3>Key Stakeholders</h3>

# %% [markdown]
# * Primary stakeholder - the director of marketing (my manager)
# * Secondary stakeholders - the marketing analytics team and the executive team

# %% [markdown]
# _____________________________________________________________________________________
# </br>
#
# <h3><center>I will deliver a presentation with insights into the difference in customers users behavior and recommended accordingly</center></h3>

# %% [markdown]
# _____________________________________________________________________________________
# <h1>2. Prepare</h1>

# %% [markdown]
# I will use <a href='https://divvy-tripdata.s3.amazonaws.com/index.html'>Cyclistic’s historical trip data </a> to analyze and identify trends. Download the 12 months of Cyclistic trip data from year 2021. (Note: The datasets have a different name because Cyclistic is a fictional company.The data has been made available by
# Motivate International Inc. under this <a href='https://ride.divvybikes.com/data-license-agreement'>license.</a> This is public data that can use to explore how different customer types are using Cyclistic bikes).
# The datasets contain 12 CSV file of rides from each months fronm year 2021. Each rides contains basic information such as the start date and time, end date and time, and whether the customer was a casual user or a member.
# </br>
# </br>
# Start Import library & data

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
# Import csv files
df12=pd.read_csv('C:\\Users\\dror\\Documents\\Data Analyst\\DATABASE\\Cyclistic bike-share\\202112-divvy-tripdata\\202112-divvy-tripdata.csv')
df11=pd.read_csv('C:\\Users\\dror\\Documents\\Data Analyst\\DATABASE\\Cyclistic bike-share\\202111-divvy-tripdata\\202111-divvy-tripdata.csv')
df10=pd.read_csv('C:\\Users\\dror\\Documents\\Data Analyst\\DATABASE\\Cyclistic bike-share\\202110-divvy-tripdata\\202110-divvy-tripdata.csv')
df9=pd.read_csv('C:\\Users\\dror\\Documents\\Data Analyst\\DATABASE\\Cyclistic bike-share\\202109-divvy-tripdata\\202109-divvy-tripdata.csv')
df8=pd.read_csv('C:\\Users\\dror\\Documents\\Data Analyst\\DATABASE\\Cyclistic bike-share\\202108-divvy-tripdata\\202108-divvy-tripdata.csv')
df7=pd.read_csv('C:\\Users\\dror\\Documents\\Data Analyst\\DATABASE\\Cyclistic bike-share\\202107-divvy-tripdata\\202107-divvy-tripdata.csv')
df6=pd.read_csv('C:\\Users\\dror\\Documents\\Data Analyst\\DATABASE\\Cyclistic bike-share\\202106-divvy-tripdata\\202106-divvy-tripdata.csv')
df5=pd.read_csv('C:\\Users\\dror\\Documents\\Data Analyst\\DATABASE\\Cyclistic bike-share\\202105-divvy-tripdata\\202105-divvy-tripdata.csv')
df4=pd.read_csv('C:\\Users\\dror\\Documents\\Data Analyst\\DATABASE\\Cyclistic bike-share\\202104-divvy-tripdata\\202104-divvy-tripdata.csv')
df3=pd.read_csv('C:\\Users\\dror\\Documents\\Data Analyst\\DATABASE\\Cyclistic bike-share\\202103-divvy-tripdata\\202103-divvy-tripdata.csv')
df2=pd.read_csv('C:\\Users\\dror\\Documents\\Data Analyst\\DATABASE\\Cyclistic bike-share\\202102-divvy-tripdata\\202102-divvy-tripdata.csv')
df1=pd.read_csv('C:\\Users\\dror\\Documents\\Data Analyst\\DATABASE\\Cyclistic bike-share\\202101-divvy-tripdata\\202101-divvy-tripdata.csv')

# %% [markdown]
# Merage 12 csv files into 1 file and naming it as "df"

# %%
df = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12], ignore_index = True)

# %% [markdown]
# * Cheking duplicate

# %%
# Supressing the warning messages
import warnings
warnings.filterwarnings('ignore')
print('Shape before deleting duplicate values:', df.shape)

# Removing duplicate rows if any
df.drop_duplicates()
print('Shape After deleting duplicate values:', df.shape)

# Printing sample data
# Start observing the Quantitative/Categorical/Qualitative variables
# Out:
# Shape before deleting duplicate values: (5595063, 13)
# Shape After deleting duplicate values: (5595063, 13)

# %% [markdown]
# <h3>Basic Data Exploration</h3>

# %%
# Looking at sample rows in the data
df.head(10)
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  E19E6F1B8D4C42ED  electric_bike  2021-01-23 16:14:19  2021-01-23 16:24:44
# 1  DC88F20C2C55F27F  electric_bike  2021-01-27 18:43:08  2021-01-27 18:47:12
# 2  EC45C94683FE3F27  electric_bike  2021-01-21 22:35:54  2021-01-21 22:37:14
# 3  4FA453A75AE377DB  electric_bike  2021-01-07 13:31:13  2021-01-07 13:42:55
# 4  BE5E8EB4E7263A0B  electric_bike  2021-01-23 02:24:02  2021-01-23 02:24:45
# 5  5D8969F88C773979  electric_bike  2021-01-09 14:24:07  2021-01-09 15:17:54
# 6  09275CC10F854E9E  electric_bike  2021-01-04 05:05:04  2021-01-04 05:10:39
# 7  DF7A32A217AEFB14  electric_bike  2021-01-14 15:07:00  2021-01-14 15:13:40
# 8  C2EFC62379EB716C  electric_bike  2021-01-09 09:57:55  2021-01-09 10:00:26
# 9  B9F73448DFBE0D45   classic_bike  2021-01-24 19:15:38  2021-01-24 19:22:51
#
#            start_station_name start_station_id        end_station_name  \
# ...

# %%
# Observing the summarized information of data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5595063 entries, 0 to 5595062
# Data columns (total 13 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       object
#  2   started_at          object
#  3   ended_at            object
#  4   start_station_name  object
#  5   start_station_id    object
#  6   end_station_name    object
#  7   end_station_id      object
#  8   start_lat           float64
#  9   start_lng           float64
#  10  end_lat             float64
#  11  end_lng             float64
#  12  member_casual       object
# dtypes: float64(4), object(9)
# memory usage: 554.9+ MB

# %%
# Looking at the descriptive statistics of the data
df.describe(include='all')
# Out:
#                  ride_id rideable_type           started_at  \
# count            5595063       5595063              5595063
# unique           5595063             3              4677998
# top     E19E6F1B8D4C42ED  classic_bike  2021-07-16 16:59:57
# freq                   1       3251028                    7
# mean                 NaN           NaN                  NaN
# std                  NaN           NaN                  NaN
# min                  NaN           NaN                  NaN
# 25%                  NaN           NaN                  NaN
# 50%                  NaN           NaN                  NaN
# 75%                  NaN           NaN                  NaN
# max                  NaN           NaN                  NaN
#
#                    ended_at       start_station_name start_station_id  \
# count               5595063                  4904254          4904257
# unique              4671372                      847              834
# ...

# %%
# Finding how many null values and amount of null values per column.
df.isnull().sum()
# Out:
# ride_id                    0
# rideable_type              0
# started_at                 0
# ended_at                   0
# start_station_name    690809
# start_station_id      690806
# end_station_name      739170
# end_station_id        739170
# start_lat                  0
# start_lng                  0
# end_lat                 4771
# end_lng                 4771
# member_casual              0
# dtype: int64

# %%
# Finging unique values for each column
# TO understand which column is categorical and which one is Continuous
df.nunique()
# Out:
# ride_id               5595063
# rideable_type               3
# started_at            4677998
# ended_at              4671372
# start_station_name        847
# start_station_id          834
# end_station_name          844
# end_station_id            832
# start_lat              394205
# start_lng              374003
# end_lat                445033
# end_lng                405226
# member_casual               2
# dtype: int64

# %% [markdown]
# ____________________________________________________________________________
# <h3>Data Organize</h3>

# %% [markdown]
# * Data contains:
#     * 5,595,063 rows
#     * 13 columns
# * Memory usage: 554.9+ MB
# * Non duplicate values
# * Data types: float64(4), object(9)
# * Columns with null:
#     * start_station_name (690,809)
#     * start_station_id (690,806)
#     * end_station_name (739,170)
#     * end_station_id (739,170)
#     * end_lat (4,771)
#     * end_lng (4,771)
#
# Additionally there is inconsistencies in the names and id of stations.
# _____________________________________________

# %% [markdown]
# <h1>3. Process</h1>

# %% [markdown]
# <h3>Cleaning Process</h3>

# %% [markdown]
# * Delete null vales in columns:
#     * start_station_name - 690,809 null
#     * start_station_id - 690,809 null
#     * end_station_name - 739,170 null
#     * end_station_id - 739,170 null
#
#
# i will rely on latitude and Llongitude columns after i will delete all rows with NULL.</br>
# after delete all null value the database contine 4.5 M rows.

# %%
# Delete rows with null
df = df.dropna(subset=['start_station_name','start_station_id','end_station_name','end_station_id'])
df.isnull().sum()
# Out:
# ride_id               0
# rideable_type         0
# started_at            0
# ended_at              0
# start_station_name    0
# start_station_id      0
# end_station_name      0
# end_station_id        0
# start_lat             0
# start_lng             0
# end_lat               0
# end_lng               0
# member_casual         0
# dtype: int64

# %%
# Cheking columns data types 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4588302 entries, 9 to 5595062
# Data columns (total 13 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       object
#  2   started_at          object
#  3   ended_at            object
#  4   start_station_name  object
#  5   start_station_id    object
#  6   end_station_name    object
#  7   end_station_id      object
#  8   start_lat           float64
#  9   start_lng           float64
#  10  end_lat             float64
#  11  end_lng             float64
#  12  member_casual       object
# dtypes: float64(4), object(9)
# memory usage: 490.1+ MB

# %%
# Cheking unigue values 
df.nunique()
# Out:
# ride_id               4588302
# rideable_type               3
# started_at            3933304
# ended_at              3925841
# start_station_name        842
# start_station_id          829
# end_station_name          839
# end_station_id            827
# start_lat              348207
# start_lng              329289
# end_lat                395771
# end_lng                359491
# member_casual               2
# dtype: int64

# %% [markdown]
# <h3>Coverting Datatype</h3>

# %% [markdown]
# <b>Transform data so we can work with it effectively</b>

# %% [markdown]
# Converting datatype of "started_at" & "ended_at" columns to "datetime64" type.

# %%
# Converting datatype of "started_at" & "ended_at" columns to "datetime64" type.
df['started_at'] = df['started_at'].astype('datetime64')
df['ended_at'] = df['ended_at'].astype('datetime64')

# %% [markdown]
# Converting datatype of "ride_id" to "string".

# %%
# Converting datatype "ride_id", "start_station_name" and "end_station_name" to "string"
df['ride_id'] = df['ride_id'].astype('str')
df['start_staion_name'] = df['start_station_name'].astype('str')
df['ens_station_name'] = df['end_station_name'].astype('str')

# %% [markdown]
# Trim all strings columns in the dataframe

# %%
# trim all strings of a dataframe
df_obj = df.select_dtypes(['object'])
df[df_obj.columns] = df_obj.apply(lambda x: x.str.strip())

# %% [markdown]
# Converting columns to category.

# %%
# Converting columns to category for saving memory usage
cols_to_exclude = ['rideable_type','start_station_name','start_station_id','end_station_name','end_station_id']
for col in df.columns:
    if df[col].nunique() < 900 and col in cols_to_exclude:
        df[col] = df[col].astype('category')

# %% [markdown]
# Coverting datatype of "member_casual" to new column 'member' as "booleans" type and delete "member_casual" column.

# %%
# Coverting datatype of "member_casual" to new column as "booleans"
# Delete "member_casual" columns that are not needed
df['member'] = np.where(df['member_casual'] == 'member', True, False)
df = df.drop(columns=['member_casual'])

# %% [markdown]
# Creating New Column "ride_length" and changing its datatype to "int32".

# %%
# Creating New Column "ride_length" and changing its datatype to "int32"
# In this column, each row contains the difference between "starting time" and "ending time" columns in minutes.
df['ride_length'] = (df['ended_at'] - df['started_at'])/pd.Timedelta(minutes=1)
df['ride_length'] = df['ride_length'].astype('int32')

# %%
# Cheking the summarized information of data after clening process
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4588302 entries, 9 to 5595062
# Data columns (total 16 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       category
#  2   started_at          datetime64[ns]
#  3   ended_at            datetime64[ns]
#  4   start_station_name  category
#  5   start_station_id    category
#  6   end_station_name    category
#  7   end_station_id      category
#  8   start_lat           float64
#  9   start_lng           float64
#  10  end_lat             float64
#  11  end_lng             float64
#  12  start_staion_name   object
#  13  ens_station_name    object
#  14  member              bool
#  15  ride_length         int32
# dtypes: bool(1), category(5), datetime64[ns](2), float64(4), int32(1), object(3)
# memory usage: 411.5+ MB

# %% [markdown]
# Creating New Column "ride_length" and changing its datatype to "int32"

# %%
# Sorting Values by "ride_length" column in Ascending order.
df.sort_values(by = 'ride_length')
# Out:
#                   ride_id  rideable_type          started_at  \
# 5129636  FD8AF7324ABAE9DA  electric_bike 2021-11-07 01:56:51
# 5113400  508B09A5FB0737DC   classic_bike 2021-11-07 01:54:50
# 5270218  7AECC76D1562B51C   classic_bike 2021-11-07 01:54:58
# 5248365  6F9E76F5EDAAC1B8  electric_bike 2021-11-07 01:55:42
# 5091563  CDB307B8494885AD  electric_bike 2021-11-07 01:55:09
# ...                   ...            ...                 ...
# 2613756  99415B003B7E7EEE    docked_bike 2021-07-08 19:29:49
# 1325528  E6E1E5BFFD72ECEC    docked_bike 2021-06-05 23:33:51
# 758503   BDA1217EC8532C7B    docked_bike 2021-05-02 02:56:07
# 1789291  7F0578ABF030FC83    docked_bike 2021-06-04 22:03:33
# 1839498  F043F0F6A1AA4F85    docked_bike 2021-06-05 02:27:26
#
#                    ended_at              start_station_name start_station_id  \
# 5129636 2021-11-07 01:00:57            Clark St & North Ave            13128
# ...

# %%
# Its seen that many rows in some months contained negative values. 
# Such errors happened because the "ending time" is earlier than the "starting time" in their respective rows.
df[df['ride_length'] < 0].count()

# Number of rows containing Negative Values.
# Out:
# ride_id               51
# rideable_type         51
# started_at            51
# ended_at              51
# start_station_name    51
# start_station_id      51
# end_station_name      51
# end_station_id        51
# start_lat             51
# start_lng             51
# end_lat               51
# end_lng               51
# start_staion_name     51
# ens_station_name      51
# member                51
# ride_length           51
# dtype: int64

# %%
# Number of rows containing "ride length" less than "1" minute.
df[df['ride_length'] < 1].count()
# Out:
# ride_id               59369
# rideable_type         59369
# started_at            59369
# ended_at              59369
# start_station_name    59369
# start_station_id      59369
# end_station_name      59369
# end_station_id        59369
# start_lat             59369
# start_lng             59369
# end_lat               59369
# end_lng               59369
# start_staion_name     59369
# ens_station_name      59369
# member                59369
# ride_length           59369
# dtype: int64

# %% [markdown]
# Removing 85.200 rows containing negative values and ride length less than 1 minute.

# %%
# Any trips that were below 1 minute lenght are probably false starts or users trying to re-dock a bike to ensure it was secure.
df = df[df['ride_length'] >= 1]
df = df.reset_index()
df = df.drop(columns=['index'])

# %% [markdown]
# <h3>Stations Name & ID Columns Exeme</h3>

# %% [markdown]
# We know there are only 692 stations.
# But there are 841 start station names and 824 ID.

# %%
df.nunique()
# Out:
# ride_id               4528933
# rideable_type               3
# started_at            3889597
# ended_at              3882166
# start_station_name        841
# start_station_id          828
# end_station_name          838
# end_station_id            826
# start_lat              346017
# start_lng              327185
# end_lat                393520
# end_lng                357289
# start_staion_name         841
# ens_station_name          838
# member                      2
# ride_length              2524
# dtype: int64

# %%
# checking  station by group by name station and count of ride id
s = df.groupby(['start_station_name','start_station_id'])
s = s.agg({"ride_id" : "count"} )
s
# Out:
#                                                      ride_id
# start_station_name   start_station_id
# 2112 W Peterson Ave  13001                                 0
#                      13006                                 0
#                      13008                                 0
#                      13011                                 0
#                      13016                                 0
# ...                                                      ...
# Yates Blvd & 93rd St TA1309000067                          0
#                      Throop/Hastings Mobile Station        0
#                      WL-008                                0
#                      WL-011                                0
#                      WL-012                                0
#
# [698018 rows x 1 columns]

# %%
# checking  station by group by ID
s = df.groupby(['start_station_id','start_station_name'])
s = s.agg({"ride_id" : "count"} )
s
# Out:
#                                                ride_id
# start_station_id start_station_name
# 13001            2112 W Peterson Ave                 0
#                  351                                 0
#                  63rd St Beach                       0
#                  900 W Harrison St                   0
#                  Aberdeen St & Jackson Blvd          0
# ...                                                ...
# WL-012           Woodlawn Ave & 55th St              0
#                  Woodlawn Ave & 75th St              0
#                  Woodlawn Ave & Lake Park Ave        0
#                  Yates Blvd & 75th St                0
#                  Yates Blvd & 93rd St                0
#
# [698018 rows x 1 columns]

# %% [markdown]
# As we can see a particular station can have multiple station identities and vice versa from one ID number to multiple stations. Because the identifiers need to be specific we can not use them.
# * i will delete station id columns

# %%
df = df.drop(['start_station_id', 'end_station_id'], axis=1)

# %% [markdown]
# i will not  round the Latitude and Longitude values.

# %% [markdown]
# * round to 4 notes after the dote.
#
# The longitude and latitude show the exact location of the bike. The round  number will unite several points close to the same station name.

# %%
# i will want to round the Latitude and Longitude stations going forward this the code:
df['start_lat'] = round(df['start_lat'], 4)
df['start_lng'] = round(df['start_lng'], 4)
df['end_lng'] = round(df['end_lng'], 4)
df['end_lat'] = round(df['end_lat'], 4)

# %%
# Cheking unigue value of stations location 
df.nunique()
# Out:
# ride_id               4528933
# rideable_type               3
# started_at            3889597
# ended_at              3882166
# start_station_name        841
# end_station_name          838
# start_lat                1627
# start_lng                1310
# end_lat                  2575
# end_lng                  1725
# start_staion_name         841
# ens_station_name          838
# member                      2
# ride_length              2524
# dtype: int64

# %% [markdown]
# <h3>Adding Date Types Columns</h3>
# create a new dataframe to include date, month as number, months names, day of week, day of week number columns and hours numbers. These columns will help us analyse trip data per month, week and daily basis.
# We already have our date in datetime format. To extract month, week and day as an object (or string), meaning get month, week and day in names instead of numbers, we will run the below code.

# %%
df = df.assign(
    date = pd.to_datetime(df['started_at']).dt.date,
    month = df['started_at'].dt.strftime("%m"),
    month_name = df['started_at'].dt.strftime("%B"),
    day_of_week = df['started_at'].dt.strftime("%A"),
    day_week_num = pd.to_datetime(df['started_at']).dt.dayofweek
)
df['hour'] = df['started_at'].dt.hour

# %% [markdown]
# Converting new columns to category to reduce memory usage

# %%
cols_to_exclude = ['month','month_name', 'day_of_week','day_week_num','hour' ]
for col in df.columns:
    if df[col].nunique() < 32 and col in cols_to_exclude:
        df[col] = df[col].astype('category')

# %% [markdown]
# <h3>Calculate Distance For each ride</h3>

# %%
# install and imoprt haversine
# !pip install haversine
import haversine as hs

# %%
# test on new dataframe
df1 = pd.DataFrame(df)

# %%
# Function to Calculate Distance
def find_km(x1,y1,x2,y2):
    return hs.haversine((x1, y1),(x2, y2))

df1['distance'] = df.apply(lambda row :
        find_km(row['start_lat'], row['start_lng'], row['end_lat'], row['end_lng']), axis=1)

# %% [markdown]
# Round km column values

# %%
# rename back to df
df = pd.DataFrame(df1)
df['distance'] = round(df['distance'], 1)

# %% [markdown]
# checking ride_length for all ride that have 0 distance. i will exem and analysis this going on!

# %%
df.loc[(df['distance'] == 0) & (df['ride_length'] >= 0)]
# Out:
#                   ride_id  rideable_type          started_at  \
# 132      614F73576809533D   classic_bike 2021-01-14 15:32:16
# 133      5B10BBB62AFC4986  electric_bike 2021-01-03 11:59:58
# 222      8527740375523C06    docked_bike 2021-01-25 17:04:53
# 223      DFCD4D55C73B88AB   classic_bike 2021-01-07 07:51:06
# 265      0C4D1DE10D5BE853  electric_bike 2021-01-05 12:53:10
# ...                   ...            ...                 ...
# 4528909  8F0471B42FE61E71   classic_bike 2021-12-17 15:18:28
# 4528910  1D17355FC340FB36   classic_bike 2021-12-12 11:54:58
# 4528912  7B34406510C26493  electric_bike 2021-12-15 12:02:58
# 4528913  82791B807949CE47  electric_bike 2021-12-19 14:56:40
# 4528914  499FFDA8E0635A96   classic_bike 2021-12-17 07:22:54
#
#                    ended_at            start_station_name  \
# 132     2021-01-14 15:34:08  Halsted St & North Branch St
# 133     2021-01-03 12:24:29      Glenwood Ave & Touhy Ave
# ...

# %% [markdown]
# <h3>Final Checking Befor Save & Analze</h3>

# %%
df.head()
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  B9F73448DFBE0D45   classic_bike 2021-01-24 19:15:38 2021-01-24 19:22:51
# 1  457C7F4B5D3DA135  electric_bike 2021-01-23 12:57:38 2021-01-23 13:02:10
# 2  57C750326F9FDABE  electric_bike 2021-01-09 15:28:04 2021-01-09 15:37:51
# 3  4D518C65E338D070  electric_bike 2021-01-09 15:28:57 2021-01-09 15:37:54
# 4  9D08A3AFF410474D   classic_bike 2021-01-24 15:56:59 2021-01-24 16:07:08
#
#            start_station_name            end_station_name  start_lat  \
# 0  California Ave & Cortez St      Wood St & Augusta Blvd    41.9004
# 1  California Ave & Cortez St  California Ave & North Ave    41.9004
# 2  California Ave & Cortez St      Wood St & Augusta Blvd    41.9004
# 3  California Ave & Cortez St      Wood St & Augusta Blvd    41.9004
# 4  California Ave & Cortez St      Wood St & Augusta Blvd    41.9004
#
#    start_lng  end_lat  end_lng  ...            ens_station_name member  \
# ...

# %%
df.describe(include='all')
# Out:
#           start_lat     start_lng       end_lat       end_lng   ride_length  \
# count  4.528933e+06  4.528933e+06  4.528933e+06  4.528933e+06  4.528933e+06
# mean   4.190308e+01 -8.764350e+01  4.190337e+01 -8.764374e+01  2.160056e+01
# std    4.030210e-02  2.327570e-02  4.044962e-02  2.348948e-02  1.856136e+02
# min    4.164850e+01 -8.783000e+01  4.164850e+01 -8.783000e+01  1.000000e+00
# 25%    4.188220e+01 -8.765550e+01  4.188260e+01 -8.765590e+01  7.000000e+00
# 50%    4.189770e+01 -8.764060e+01  4.189820e+01 -8.764100e+01  1.200000e+01
# 75%    4.192630e+01 -8.762770e+01  4.192680e+01 -8.762770e+01  2.200000e+01
# max    4.206490e+01 -8.752820e+01  4.216810e+01 -8.752450e+01  5.594400e+04
#
#            distance
# count  4.528933e+06
# mean   2.156429e+00
# std    1.876451e+00
# min    0.000000e+00
# 25%    9.000000e-01
# 50%    1.600000e+00
# 75%    2.800000e+00
# max    3.380000e+01

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4528933 entries, 0 to 4528932
# Data columns (total 21 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       category
#  2   started_at          datetime64[ns]
#  3   ended_at            datetime64[ns]
#  4   start_station_name  category
#  5   end_station_name    category
#  6   start_lat           float64
#  7   start_lng           float64
#  8   end_lat             float64
#  9   end_lng             float64
#  10  start_staion_name   object
#  11  ens_station_name    object
#  12  member              bool
#  13  ride_length         int32
#  14  date                object
#  15  month               category
#  16  month_name          category
#  17  day_of_week         category
#  18  day_week_num        category
#  19  hour                category
#  20  distance            float64
# ...

# %%
df.nunique()
# Out:
# ride_id               4528933
# rideable_type               3
# started_at            3889597
# ended_at              3882166
# start_station_name        841
# end_station_name          838
# start_lat                1627
# start_lng                1310
# end_lat                  2575
# end_lng                  1725
# start_staion_name         841
# ens_station_name          838
# member                      2
# ride_length              2524
# date                      365
# month                      12
# month_name                 12
# day_of_week                 7
# day_week_num                7
# hour                       24
# distance                  276
# dtype: int64

# %% [markdown]
# Converting new columns 'start_lat', 'stsrt_lng','end_lat','end_lng' to category to reduce memory usage

# %%
# Converting "date" column to datatype "datetime64".
df['date'] = df['date'].astype('datetime64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4528933 entries, 0 to 4528932
# Data columns (total 21 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       category
#  2   started_at          datetime64[ns]
#  3   ended_at            datetime64[ns]
#  4   start_station_name  category
#  5   end_station_name    category
#  6   start_lat           float64
#  7   start_lng           float64
#  8   end_lat             float64
#  9   end_lng             float64
#  10  start_staion_name   object
#  11  ens_station_name    object
#  12  member              bool
#  13  ride_length         int32
#  14  date                datetime64[ns]
#  15  month               category
#  16  month_name          category
#  17  day_of_week         category
#  18  day_week_num        category
#  19  hour                category
#  20  distance            float64
# ...

# %% [markdown]
# <h3>note</h3> <b>data-privacy issues prohibit me from using riders personally identifiable information. This
# means that i will not be able to connect pass purchases to credit card numbers to determine if casual riders live in the
# Cyclistic service area or if they have purchased multiple single passes.</b>

# %% [markdown]
# <h1>4. Analze</h1>

# %%
# save data as csv file
df.to_csv('Cyclistic-bike-share-2021.csv')

# %%
# import libaray
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# Set up with a higher resolution screen
plt.rcParams["figure.figsize"] = [10, 6]
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# <h3>Calculation the total members and casuals users in year 2021</h3>

# %%
# pivot table of members (False = Casual User)
pd.pivot_table(
    df,
    index = 'member',
    values = 'ride_id',
    aggfunc = 'count',
    margins = True,
    margins_name = 'Total Count'
)
# Out:
#              ride_id
# member
# False        2027937
# True         2500996
# Total Count  4528933

# %%
# plot bar of total members and casuals users in year 2021
member = sum(df.member == True) # member list count
casual = sum(df.member == False) # casual list count
users = ['member', 'casual']
amount = [member, casual]

barplt = plt.bar(users,amount)
barplt[1].set_color('orange')

plt.ylabel("Number of Rides (in millions)")
plt.title(label='2021 Total Rides\n Members Vs Casuals ')
# Out:
# Text(0.5, 1.0, '2021 Total Rides\n Members Vs Casuals ')

# %% [markdown]
# * Members ride more than casuals users

# %% [markdown]
# <h3>Bikes Types</h3>

# %%
bt = df.groupby(['member','rideable_type'], as_index=False).agg({'ride_id' : 'count'})

m = bt.loc[(df['member'] == True)]
m = m.drop(['member'], axis=1)
m.columns = ['Bike Type','Members']
m = m.set_index('Bike Type')

c = bt.loc[(df['member'] == False)]
c = c.drop(['member'], axis=1)
c.columns = ['Bike Type','Casual']
c = c.set_index('Bike Type')

m['Casual'] = c
m
# Out:
#                Members   Casual
# Bike Type
# classic_bike   1248437  1951820
# docked_bike     310098        1
# electric_bike   549175   469402

# %%
m.plot.bar()
plt.xticks(rotation=0)
plt.xlabel("Bike Type")
plt.ylabel("Count Of Ride (in millions)")
plt.title('2021 Bike Type Ride\nMeber Vs Casual')
# Out:
# Text(0.5, 1.0, '2021 Bike Type Ride\nMeber Vs Casual')

# %%
btm = pd.DataFrame(df.groupby(['date','rideable_type'], as_index=False).agg({'ride_id' : 'count'}))
btm = btm.assign(
    day_of_week = btm['date'].dt.strftime("%A"),
    day_week_num = pd.to_datetime(btm['date']).dt.dayofweek)

rtc = btm.loc[(btm['rideable_type'] == 'classic_bike')]
rtc = rtc.drop(['rideable_type'], axis=1)
rtc.columns = ['Date','Classic Bike', 'Day','Day_num']
rtc = rtc.groupby(['Day_num','Day'], as_index=True).agg({'Classic Bike' : np.mean})
rtc['Classic Bike'] = rtc['Classic Bike'].astype(int)

rtd = btm.loc[(btm['rideable_type'] == 'docked_bike')]
rtd = rtd.drop(['rideable_type'], axis=1)
rtd.columns = ['Date','Docked Bike','Day','Day_num']
rtd = rtd.groupby(['Day_num','Day'], as_index=True).agg({'Docked Bike' : np.mean})
rtd['Docked Bike'] = rtd['Docked Bike'].astype(int)

rte = btm.loc[(btm['rideable_type'] == 'electric_bike')]
rte = rte.drop(['rideable_type'], axis=1)
rte.columns = ['Date','Electric Bike','Day','Day_num']
rte = rte.groupby(['Day_num','Day'], as_index=True).agg({'Electric Bike' : np.mean})
rte['Electric Bike'] = rte['Electric Bike'].astype(int)

a = rtc
a['Docked Bike'] = rtd
a['Electric Bike'] = rte
a = a.reset_index()
a = a.drop(['Day_num'], axis=1)
a
# Out:
#          Day  Classic Bike  Docked Bike  Electric Bike
# 0     Monday          7691          696           2531
# 1    Tuesday          8044          565           2838
# 2  Wednesday          8312          528           2851
# 3   Thursday          8059          528           2760
# 4     Friday          8519          788           2907
# 5   Saturday         11108         1498           3063
# 6     Sunday          9643         1344           2578

# %%
x = a['Day']
x_axis = np.arange(len(x))

bar1 = plt.bar(x_axis -0.25 ,a['Classic Bike'],0.25, label = 'Classic Bike')
bar2 = plt.bar(x_axis +0.25 ,a['Docked Bike'],0.25, label = 'Docked Bike')
bar3 = plt.bar(x_axis ,a['Electric Bike'],0.25, label = 'Electric Bike')

plt.xlabel("Day of Week")
plt.ylabel('Average Rides')
plt.title("Average Ride for Bike Type\n Day Of Week")
  
plt.xticks(x_axis,['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday'])
plt.legend((bar1,bar3,bar2),('Classic Bike', 'Docked Bike','Electric Bike'), loc=2)
plt.show()

# %% [markdown]
#  * Classic Bike are the most rideable type that all users ride.

# %% [markdown]
# <h3>Calculation the total members and casuals users in each month in year 2021</h3>

# %%
# create data frame for plot
# A total count of users per day
fy = df.groupby(['date','member'], as_index=False).agg({'ride_id' : 'count'}) # A total count of users per day

# create a data frame
fy = pd.DataFrame(fy) 

# adding columns of month (name & number)
fy = fy.assign(
    month = fy['date'].dt.strftime("%m"),
    month_name = fy['date'].dt.strftime("%B"))

# create a list of member only cunt rides per days:
m = fy.loc[(fy['member'] == True)] # list of all members rides per days
m = m.drop(['date','member'], axis=1) # drop "member" & "date" columns 
m.columns = ['Member','month','Month'] # change columns name
m = pd.DataFrame(m.groupby(
    ['month','Month'], as_index=True)['Member'].sum()) # group by to month & index the dataframe

# create a list of member only cunt rides per days:
c = fy.loc[(fy['member'] == False)] # list of all members rides per days
c = c.drop(['date','member'], axis=1) # drop "member" & "date" columns 
c.columns = ['Casual','month','Month'] # change columns name
c = pd.DataFrame(c.groupby(['month','Month'], as_index=True)['Casual'].sum()) # group by to month & index the dataframe

# organize dataframe for member list to merge casuals count column
m['Casual'] = c
m = m.reset_index() # reset index to 
m = m.set_index('Month') # set index by month name
m = m.drop(['month'], axis=1) # drop month number 
m
# Out:
#            Member  Casual
# Month
# January     68039   14583
# February    33793    8508
# March      128349   75059
# April      175261  119362
# May        230505  214652
# June       299743  300769
# July       317690  365513
# August     327946  338138
# September  323287  290078
# October    284140  187324
# November   182922   69267
# December   129321   44684

# %%
m.plot.bar()
plt.xticks(rotation=30)
plt.ylabel("Number of Rides")
plt.title('2021 Total Rides\n Members Vs Casuals ')
# Out:
# Text(0.5, 1.0, '2021 Total Rides\n Members Vs Casuals ')

# %% [markdown]
# * In the winter months there is a significant decrease in the amount of members and csauals ride.
# * In the summer months there is a significant increase in the amount of members and csauals ride.
# * In the summer months casuals ride more than members.

# %%
m.plot.line()
plt.xticks(rotation=0)
plt.ylabel("Number of Rides")
plt.title('2021 Total Rides\n Members Vs Casuals ')
# Out:
# Text(0.5, 1.0, '2021 Total Rides\n Members Vs Casuals ')

# %% [markdown]
# <h3>Day Average Rides - Day Of Week</h3>

# %%
# create data frame for plot
# Average rides per day of week
fy = pd.DataFrame(df.groupby(['date','member'], as_index=False).agg({'ride_id' : 'count'})) # A total count of users per day and create a data frame
fy = fy.assign(day_of_week = fy['date'].dt.strftime("%A"),day_week_num = pd.to_datetime(fy['date']).dt.dayofweek) # add day of week name and numbers columns
fy = fy.groupby(['day_week_num','day_of_week'], as_index=True).agg({'ride_id' : np.mean}) # group by day of week and avearge ride 
fy = fy.rename(columns={'ride_id': 'Average Rides'}) # rename column
fy['Average Rides'] = fy['Average Rides'].astype(int) # change data type to int
fy = fy.reset_index() # reset index to 
fy = fy.set_index('day_of_week') # set index by month name
fy = fy.drop(['day_week_num'], axis=1) # drop month number 
fy
# Out:
#              Average Rides
# day_of_week
# Monday                5459
# Tuesday               5724
# Wednesday             5846
# Thursday              5674
# Friday                6107
# Saturday              7835
# Sunday                6783

# %%
fy.plot.bar()
plt.xticks(rotation=0)
plt.xlabel("Day Of Week")
plt.ylabel("Average Rides")
plt.title('2021 Average Ride \n Day of Week')
# Out:
# Text(0.5, 1.0, '2021 Average Ride \n Day of Week')

# %% [markdown]
# * On weekends the average amount of ride are higher than on the weekdays.

# %% [markdown]
# <h3>Members Vs Casual Day Average Rides - Day Of Week</h3>

# %%
# create data frame for plot
# Average rides per day of week
fy = pd.DataFrame(df.groupby(['date','member'], as_index=False).agg(
    {'ride_id' : 'count'})) # A total count of users per day and create a data frame
fy = fy.assign(day_of_week = fy['date'].dt.strftime(
    "%A"),day_week_num = pd.to_datetime(
    fy['date']).dt.dayofweek) # add day of week name and numbers columns
fy = fy.groupby(['day_week_num','day_of_week','member'], as_index=True).agg(
    {'ride_id' : np.mean}) # group by day of week and avearge ride 
fy = fy.rename(columns={'ride_id': 'Average Rides'}) # rename column
fy = fy.reset_index() # reset index to 
fy = fy.set_index('day_of_week') # set index by month name
fy = fy.drop(['day_week_num'], axis=1) # drop month number

# %%
# create list of member only from the data frame
m = fy.loc[(fy['member'] == True)].astype(int)
m = m.drop(['member'], axis=1)
m.columns = ['Member']
m = m.reset_index()

# create list of casual only from the data frame
c = fy.loc[(fy['member'] == False)].astype(int)
c = c.drop(['member'], axis=1)
c.columns = ['Casual']
c = c.reset_index()

# add casual mean column to member data frame 
m['Casual'] = c['Casual']
m
# Out:
#   day_of_week  Member  Casual
# 0      Monday    6560    4358
# 1     Tuesday    7355    4092
# 2   Wednesday    7538    4153
# 3    Thursday    7078    4270
# 4      Friday    6796    5418
# 5    Saturday    6753    8917
# 6      Sunday    5882    7683

# %%
m.plot.bar(x = 'day_of_week')
plt.xticks(rotation=0)
plt.xlabel("Day Of Week")
plt.ylabel("Average Rides")
plt.title('2021 Average Ride Day of Week\nMembers Vs Casuals')
# Out:
# Text(0.5, 1.0, '2021 Average Ride Day of Week\nMembers Vs Casuals')

# %% [markdown]
# * Members ride on average more during the daysweek compared to weekends.
# * Casual on the other hand ride on average much more on weekends.
# * At the weekend the average amount of casuals is much greater than the average amount of members.

# %%
m.plot.line(x = 'day_of_week')
plt.xticks(rotation=0)
plt.xlabel("Day Of Week")
plt.ylabel("Average Rides")
plt.title('2021 Average Ride Day of Week\nMembers Vs Casuals')
# Out:
# Text(0.5, 1.0, '2021 Average Ride Day of Week\nMembers Vs Casuals')

# %% [markdown]
# <h3> Average Ride By Hour Of The Day</h3>

# %%
member = df.loc[(df['member'] == True)] # member only list
casual = df.loc[(df['member'] == False)] # casual only list

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

# %%
sns.histplot(data=df, x="hour" ,bins = 24, binwidth=0.8, color='g').set_title('Rides By Hour Of The Day')
# Out:
# Text(0.5, 1.0, 'Rides By Hour Of The Day')

# %%
sns.histplot(data=member, x="hour" ,bins = 24, binwidth=0.8,color='blue').set_title('Members Rides By Hour Of The Day')
# Out:
# Text(0.5, 1.0, 'Members Rides By Hour Of The Day')

# %%
sns.histplot(data=casual, x="hour" ,bins = 24, binwidth=0.8,color='orange').set_title('Casuals Rides By Hour Of The Day')
# Out:
# Text(0.5, 1.0, 'Casuals Rides By Hour Of The Day')

# %%
sns.histplot(data=member, x="hour" ,bins = 24, binwidth=0.8,color='blue').annotate('Members Rides To Work',xy=(7.5,140000),xytext=(4,180000),arrowprops=dict(facecolor='black', shrink=0.05))
sns.histplot(data=casual, x="hour" ,bins = 24, binwidth=0.8,color='orange',alpha=0.6).set_title('Rides By Hour Of The Day\nMembers Vs Casuals')
plt.legend(loc='upper left', labels=['Member', 'Casual'])

# %% [markdown]
# * Members ride more on average during most of the day. During rush hour in the morning and afternoon, the number of rides increases significantly.
# * Most of Casual ride duing between 11:00 am to 20:00 pm.

# %% [markdown]
# <h3> Average Length & Distance Rides</h3>

# %%
df.groupby(df['member']).agg({'ride_length' : 'mean'})
# Out:
#         ride_length
# member
# False     32.341510
# True      12.891249

# %% [markdown]
#  * Casual ride length Avreage is 32 minutes and members is 12 minutes.

# %%
df.groupby(df['member']).agg({'distance' : 'mean'})
# Out:
#         distance
# member
# False   2.202485
# True    2.119085

# %% [markdown]
# * Casual and Members distance ride average are almost the same 2.1 - 2.2 km.

# %% [markdown]
# <h3>Top Popular Station</h3>

# %% [markdown]
# <h4>Members</h4>

# %%
# Top 10 start station for members
m = member.groupby(['start_station_name']).agg(
    {'ride_id' : 'count', 'ride_length' : 'mean','distance': 'mean'})
m.nlargest(10, 'ride_id')
# Out:
#                            ride_id  ride_length  distance
# start_station_name
# Clark St & Elm St            23571    11.816003  1.958449
# Wells St & Concord Ln        22474    11.637492  2.107466
# Kingsbury St & Kinzie St     22359     9.505255  1.576994
# Wells St & Elm St            19978    10.501151  1.798628
# Dearborn St & Erie St        18365    12.070297  1.675181
# St. Clair St & Erie St       18029    13.892950  2.249004
# Wells St & Huron St          18009     9.544172  1.581537
# Broadway & Barry Ave         16734    12.839369  2.145566
# Clinton St & Madison St      16132    11.007811  1.688216
# Desplaines St & Kinzie St    15904     9.037726  1.630804

# %%
# Top 10 end station for members
m = member.groupby(['end_station_name']).agg(
    {'ride_id' : 'count', 'ride_length' : 'mean','distance': 'mean'})
m.nlargest(10, 'ride_id')
# Out:
#                           ride_id  ride_length  distance
# end_station_name
# Clark St & Elm St           23642    12.048811  1.932400
# Wells St & Concord Ln       23121    11.091735  2.067679
# Kingsbury St & Kinzie St    22545     8.803815  1.601415
# Wells St & Elm St           20532    10.265683  1.747243
# Dearborn St & Erie St       19024    12.628101  1.637468
# St. Clair St & Erie St      17855    12.497900  2.082744
# Wells St & Huron St         17672     9.593368  1.604442
# Broadway & Barry Ave        17317    13.031414  2.244205
# Clinton St & Madison St     16524    10.392036  1.675811
# Green St & Madison St       16076    11.365203  1.862099

# %% [markdown]
# <h4>Casual</h4>

# %%
# Top 10 start station for casuals
c = casual.groupby(['start_station_name']).agg(
    {'ride_id' : 'count', 'ride_length' : 'mean','distance': 'mean'})
c.nlargest(10, 'ride_id')
# Out:
#                             ride_id  ride_length  distance
# start_station_name
# Streeter Dr & Grand Ave       63724    43.374129  2.204727
# Millennium Park               31842    55.703128  1.581226
# Michigan Ave & Oak St         28350    44.157637  2.376399
# Shedd Aquarium                22293    39.832234  2.242834
# Theater on the Lake           20390    35.660569  2.667695
# Lake Shore Dr & Monroe St     18889    48.135105  1.718180
# Wells St & Concord Ln         18706    20.276222  2.327403
# Clark St & Lincoln Ave        16137    26.010287  2.353052
# Wells St & Elm St             15687    17.635941  1.963435
# Indiana Ave & Roosevelt Rd    15645    43.812017  1.953180

# %%
# Top 10 end station for casuals
c = casual.groupby(['end_station_name']).agg(
    {'ride_id' : 'count', 'ride_length' : 'mean','distance': 'mean'})
c.nlargest(10, 'ride_id')
# Out:
#                                     ride_id  ride_length  distance
# end_station_name
# Streeter Dr & Grand Ave               66802    41.893132  2.246907
# Millennium Park                       33401    42.136194  1.626882
# Michigan Ave & Oak St                 30053    40.869630  2.382787
# Theater on the Lake                   22077    37.946732  2.947275
# Shedd Aquarium                        20907    35.242216  2.307419
# Wells St & Concord Ln                 18445    20.234101  2.214432
# Lake Shore Dr & Monroe St             17736    43.938261  2.086620
# Lake Shore Dr & North Blvd            16918    35.562419  2.715599
# DuSable Lake Shore Dr & North Blvd    16493    31.282483  2.774298
# Wabash Ave & Grand Ave                16410    41.943205  1.598056

# %%
c = casual.groupby(['start_station_name','end_station_name']).agg(
    {'ride_id' : 'count', 'ride_length' : 'mean','distance': 'mean'})
c.nlargest(10, 'ride_id')
# Out:
#                                                                      ride_id  \
# start_station_name                end_station_name
# Streeter Dr & Grand Ave           Streeter Dr & Grand Ave              10957
# Millennium Park                   Millennium Park                       5768
# Michigan Ave & Oak St             Michigan Ave & Oak St                 5588
# Lake Shore Dr & Monroe St         Lake Shore Dr & Monroe St             4473
# Streeter Dr & Grand Ave           Millennium Park                       3309
# Buckingham Fountain               Buckingham Fountain                   3305
# Theater on the Lake               Theater on the Lake                   2989
# DuSable Lake Shore Dr & Monroe St DuSable Lake Shore Dr & Monroe St     2940
# Millennium Park                   Streeter Dr & Grand Ave               2927
# Montrose Harbor                   Montrose Harbor                       2907
#
# ...

# %% [markdown]
# <h4>Examining Casual cycling routes</h4>

# %%
member = df.loc[(df['member'] == True)] # member only list
casual = df.loc[(df['member'] == False)] # casual only list
casual['day_week_num'] = casual['day_week_num'].astype('int')
member['day_week_num'] = member['day_week_num'].astype('int')

# %%
# top 10 start & end station rides for casual
cs = casual.groupby(['start_station_name']).agg(
    {"ride_length" : ["count","mean"],'distance':'mean','start_lat' : 'mean', 'start_lng' : 'mean','end_lat':'mean','end_lng':'mean','day_week_num':'mean'})
cs = cs.dropna()
cs = cs.reset_index()
cs['length_mean'] = cs['ride_length','mean']
cs['length_count'] = cs['ride_length','count']
cs['distance_mean'] = cs['distance']
cs['day_mean'] = cs['day_week_num']
cs = cs.drop(['ride_length','distance','day_week_num'], axis=1)
cs = cs.sort_values(by=['length_count','length_mean'], ascending=False)
cs ['s_lat'] = cs['start_lat','mean']
cs ['s_lng'] = cs['start_lng','mean']
cs = cs.drop(['start_lat','start_lng'], axis=1)
cs.nlargest(10, 'length_count')
# Out:
#              start_station_name    end_lat    end_lng length_mean  \
#                                       mean       mean
# 730     Streeter Dr & Grand Ave  41.895087 -87.625766   43.374129
# 532             Millennium Park  41.884312 -87.624950   55.703128
# 526       Michigan Ave & Oak St  41.906436 -87.631157   44.157637
# 658              Shedd Aquarium  41.880691 -87.621275   39.832234
# 733         Theater on the Lake  41.918665 -87.636841   35.660569
# 425   Lake Shore Dr & Monroe St  41.885396 -87.621022   48.135105
# 779       Wells St & Concord Ln  41.914032 -87.643279   20.276222
# 159      Clark St & Lincoln Ave  41.917669 -87.642527   26.010287
# 780           Wells St & Elm St  41.902487 -87.640155   17.635941
# 360  Indiana Ave & Roosevelt Rd  41.877788 -87.625043   43.812017
#
#     length_count distance_mean  day_mean      s_lat      s_lng
#
# 730        63724      2.204727  3.725472  41.892293 -87.612011
# ...

# %%
# describe casual behavior that ride more than 15 minute ride.  
casual.describe().round(3)
# Out:
#          start_lat    start_lng      end_lat      end_lng  ride_length  \
# count  2027937.000  2027937.000  2027937.000  2027937.000  2027937.000
# mean        41.903      -87.642       41.903      -87.642       32.342
# std          0.040        0.024        0.040        0.025      276.315
# min         41.648      -87.830       41.648      -87.830        1.000
# 25%         41.882      -87.654       41.883      -87.654        9.000
# 50%         41.898      -87.638       41.898      -87.638       16.000
# 75%         41.926      -87.625       41.926      -87.625       30.000
# max         42.065      -87.528       42.168      -87.524    55944.000
#
#        day_week_num     distance
# count   2027937.000  2027937.000
# mean          3.538        2.202
# std           2.018        1.978
# min           0.000        0.000
# 25%           2.000        1.000
# 50%           4.000        1.700
# 75%           5.000        2.900
# max           6.000       33.800

# %%
# create a member list for tableau data visualization
ms = member.groupby(['start_station_name']).agg(
    {"ride_length" : ["count","mean"],'distance':'mean','start_lat' : 'mean', 'start_lng' : 'mean','end_lat':'mean','end_lng':'mean','day_week_num':'mean'})
ms = ms.dropna()
ms = ms.reset_index()
ms['length_mean'] = ms['ride_length','mean']
ms['length_count'] = ms['ride_length','count']
ms['distance_mean'] = ms['distance']
ms['day_mean'] = ms['day_week_num']
ms = ms.drop(['ride_length','distance','day_week_num'], axis=1)
ms = ms.sort_values(by=['length_count','length_mean'], ascending=False)
ms ['s_lat'] = ms['start_lat','mean']
ms ['s_lng'] = ms['start_lng','mean']
ms = ms.drop(['start_lat','start_lng'], axis=1)
ms.nlargest(10, 'length_count')
# Out:
#             start_station_name    end_lat    end_lng length_mean length_count  \
#                                      mean       mean
# 145          Clark St & Elm St  41.902825 -87.637846   11.816003        23571
# 753      Wells St & Concord Ln  41.911015 -87.641452   11.637492        22474
# 388   Kingsbury St & Kinzie St  41.892931 -87.640929    9.505255        22359
# 754          Wells St & Elm St  41.901682 -87.638972   10.501151        19978
# 220      Dearborn St & Erie St  41.896932 -87.636212   12.070297        18365
# 676     St. Clair St & Erie St  41.897707 -87.638136   13.892950        18029
# 757        Wells St & Huron St  41.897496 -87.637207    9.544172        18009
# 58        Broadway & Barry Ave  41.933856 -87.648061   12.839369        16734
# 168    Clinton St & Madison St  41.886271 -87.641379   11.007811        16132
# 225  Desplaines St & Kinzie St  41.892291 -87.644446    9.037726        15904
#
#     distance_mean  day_mean      s_lat      s_lng
#
# ...

# %%
#export csv files for member and casual for tableau data visualization
cs.to_csv('Cyclistic-bike-share-Casual_ride_by_stations.csv')
ms.to_csv('Cyclistic-bike-share-Member_ride_by_stations.csv')

# %%
member.loc[(member['ride_length'] >= 1)].describe().round(3)
# Out:
#          start_lat    start_lng      end_lat      end_lng  ride_length  \
# count  2500996.000  2500996.000  2500996.000  2500996.000  2500996.000
# mean        41.903      -87.645       41.904      -87.645       12.891
# std          0.040        0.022        0.041        0.022       17.613
# min         41.648      -87.830       41.648      -87.830        1.000
# 25%         41.882      -87.658       41.882      -87.658        5.000
# 50%         41.898      -87.643       41.898      -87.643        9.000
# 75%         41.929      -87.631       41.929      -87.631       16.000
# max         42.065      -87.528       42.065      -87.528     1495.000
#
#        day_week_num     distance
# count   2500996.000  2500996.000
# mean          2.920        2.119
# std           1.948        1.789
# min           0.000        0.000
# 25%           1.000        0.900
# 50%           3.000        1.600
# 75%           5.000        2.800
# max           6.000       31.600

# %%
casual.loc[(casual['ride_length'] >= 1)].describe().round(3)
# Out:
#          start_lat    start_lng      end_lat      end_lng  ride_length  \
# count  2027937.000  2027937.000  2027937.000  2027937.000  2027937.000
# mean        41.903      -87.642       41.903      -87.642       32.342
# std          0.040        0.024        0.040        0.025      276.315
# min         41.648      -87.830       41.648      -87.830        1.000
# 25%         41.882      -87.654       41.883      -87.654        9.000
# 50%         41.898      -87.638       41.898      -87.638       16.000
# 75%         41.926      -87.625       41.926      -87.625       30.000
# max         42.065      -87.528       42.168      -87.524    55944.000
#
#        day_week_num     distance
# count   2027937.000  2027937.000
# mean          3.538        2.202
# std           2.018        1.978
# min           0.000        0.000
# 25%           2.000        1.000
# 50%           4.000        1.700
# 75%           5.000        2.900
# max           6.000       33.800

# %%
casual.loc[(casual['ride_length'] >= 1440)].describe().round(3)
# Out:
#        start_lat  start_lng   end_lat   end_lng  ride_length  day_week_num  \
# count   1259.000   1259.000  1259.000  1259.000     1259.000      1259.000
# mean      41.893    -87.641    41.893   -87.650     7022.630         3.679
# std        0.061      0.033     0.064     0.035     8379.422         2.065
# min       41.658    -87.775    41.648   -87.775     1440.000         0.000
# 25%       41.878    -87.660    41.876   -87.678     2075.500         2.000
# 50%       41.892    -87.632    41.890   -87.646     3468.000         4.000
# 75%       41.921    -87.622    41.923   -87.626     8113.500         5.000
# max       42.065    -87.528    42.065   -87.528    55944.000         6.000
#
#        distance
# count  1259.000
# mean      3.427
# std       3.749
# min       0.000
# 25%       0.900
# 50%       2.300
# 75%       4.900
# max      27.700

# %%
casual.loc[(casual['distance'] == 0)].describe().round(3)
# Out:
#         start_lat   start_lng     end_lat     end_lng  ride_length  \
# count  203449.000  203449.000  203449.000  203449.000   203449.000
# mean       41.894     -87.636      41.894     -87.636       54.746
# std         0.055       0.030       0.055       0.030      192.901
# min        41.648     -87.830      41.648     -87.830        1.000
# 25%        41.876     -87.650      41.876     -87.650       16.000
# 50%        41.892     -87.629      41.892     -87.629       36.000
# 75%        41.924     -87.619      41.924     -87.619       67.000
# max        42.065     -87.528      42.065     -87.528    29960.000
#
#        day_week_num  distance
# count    203449.000  203449.0
# mean          3.516       0.0
# std           2.118       0.0
# min           0.000       0.0
# 25%           2.000       0.0
# 50%           4.000       0.0
# 75%           5.000       0.0
# max           6.000       0.0

# %%
# top 50 start stations for casual that ride bteween 0.5 - 24 hours 
# and less than 5 km distance 
# create avreage ride lenght
c=casual.loc[(casual['ride_length'] <= 1440)&(casual['distance'] <=5)&(casual['ride_length'] >= 30)]
sc10 = c.groupby(['start_station_name']).agg(
    {'ride_id':'count','ride_length':'mean'}).sort_values(
    by=['ride_id'], ascending=False).nlargest(
    50, 'ride_id').reset_index()
sc10
# Out:
#                      start_station_name  ride_id  ride_length
# 0               Streeter Dr & Grand Ave    24796    65.215277
# 1                       Millennium Park    14572    71.315674
# 2                 Michigan Ave & Oak St    10895    69.100413
# 3             Lake Shore Dr & Monroe St     8556    66.196470
# 4                        Shedd Aquarium     7908    58.990769
# 5     DuSable Lake Shore Dr & Monroe St     6266    63.565432
# 6                   Theater on the Lake     5800    64.643103
# 7                   Buckingham Fountain     5768    72.877774
# 8                        Dusable Harbor     5594    66.156239
# 9            Indiana Ave & Roosevelt Rd     5427    70.274000
# 10         Michigan Ave & Washington St     5260    77.053992
# 11                Michigan Ave & 8th St     5197    71.822782
# 12               Michigan Ave & Lake St     4760    72.109034
# 13                 New St & Illinois St     4440    70.329955
# ...

# %%
print('Total casual ride for top 50 start station: ',sc10['ride_id'].sum())
# Out:
# Total casual ride for top 50 start station:  211232

# %%
print('Total casual ride between 0.5-24 hours and less than 5 km distance: ',c['ride_id'].count())
# Out:
# Toatl casual ride between 0.5-24 hours and less than 5 km distance:  413869

# %%
c0 = casual.loc[(casual['distance']>=0)&(casual['ride_length'] >= 15)]
print('Total casual ride that ride more than 15 minutes: ',c0['ride_id'].count())
# Out:
# Total casual ride that ride more than 15 minutes:  1122536

# %%
casual.loc[(casual['ride_length'] >= 15)].describe().round(3)
# Out:
#          start_lat    start_lng      end_lat      end_lng  ride_length  \
# count  1122536.000  1122536.000  1122536.000  1122536.000  1122536.000
# mean        41.900      -87.639       41.901      -87.639       51.591
# std          0.041        0.025        0.041        0.026      370.260
# min         41.648      -87.830       41.648      -87.830       15.000
# 25%         41.881      -87.652       41.881      -87.653       20.000
# 50%         41.894      -87.634       41.895      -87.634       28.000
# 75%         41.924      -87.624       41.926      -87.624       47.000
# max         42.065      -87.528       42.168      -87.524    55944.000
#
#        day_week_num     distance
# count   1122536.000  1122536.000
# mean          3.684        2.788
# std           2.036        2.402
# min           0.000        0.000
# 25%           2.000        1.000
# 50%           4.000        2.500
# 75%           5.000        4.000
# max           6.000       33.800

# %% [markdown]
# <h3>Pattern behavior in areas of interest in the city</h3>
#
# * 1.1 millions Casuals ride more than 15 minutes for each ride.
# * there is small pattern Casual behavior to takes bike for a longs ride (can get to almost one hour ride) and return to the same station.
# * 75% of 1,122,563 Casuals rides avreage are 47 minutes and 4 km long ride.

# %%
sns.relplot(data=casual, x="distance", y="ride_length")

# %%
sns.relplot(data=c, x="distance", y="ride_length")

# %% [markdown]
# <h1>5. Share</h1>

# %% [markdown]
# * Casual riders ride more during the weekend in month of may to october. In july the number of rides is highest!
# * The average duration of a casual ride is 30 minutes (twice as high as member).
# * Stations that are in areas of interest in the city are in the top 10 station start or end.

# %% [markdown]
# <h1>6. Act</h1>

# %% [markdown]
# <h3>Recommendations</h3>
#
# * Offer a new membership track for half a year / spring-summer season / weekends only.
# * Marketing of recommended riding tours for casuals near to areas of interest in the city.
# * Collaboration with tourism, cultural and local businesses in the city that are close to top stations such as:
#     * Shedd Aquarium
#     * Adler Planetarium
#     * Theater on the Lake
#     * Chicago Harbor
#     * Montrose Harbor
#     * Buckingham Fountain
#     * Millennium Park
